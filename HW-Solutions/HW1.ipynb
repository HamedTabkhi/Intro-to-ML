# %% [markdown]
# <a href="https://colab.research.google.com/github/HamedTabkhi/Intro-to-ML/blob/main/Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/UNCC/Fall22
# Out:
# /content/gdrive/MyDrive/UNCC/Fall22

# %%
cd Intro\ to\ ML
# Out:
# /content/gdrive/MyDrive/UNCC/Fall22/Intro to ML

# %%
cd Homeworks/HW0
# Out:
# /content/gdrive/MyDrive/UNCC/Fall22/Intro to ML/Homeworks/HW0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D3.csv')
df.head() # To get first n rows from the dataset default value of n is 5
M=len(df)
M
# Out:
# 100

# %%
def compute_cost(X, y, theta):
 """
 Compute cost for linear regression.
 Input Parameters
 ----------------
 X : 2D array where each row represent the training example and each column represent
 m= number of training examples
 n= number of features (including X_0 column of ones)
 y : 1D array of labels/target value for each traing example. dimension(1 x m)
 theta : 1D array of fitting parameters or weights. Dimension (1 x n)
 Output Parameters
 -----------------
 J : Scalar value.
 """
 predictions = X.dot(theta)
 errors = np.subtract(predictions, y)
 sqrErrors = np.square(errors)
 J = 1 / (2 * m) * np.sum(sqrErrors)
 return J

def gradient_descent(X, y, theta, alpha, iterations):
    """
    Compute cost for linear regression.
    Input Parameters
    ----------------
    X : 2D array where each row represent the training example and each column represent
    m= number of training examples
    n= number of features (including X_0 column of ones)
    y : 1D array of labels/target value for each traing example. dimension(m x 1)
    theta : 1D array of fitting parameters or weights. Dimension (1 x n)
    alpha : Learning rate. Scalar value
    iterations: No of iterations. Scalar value.
    Output Parameters
    -----------------
    theta : Final Value. 1D array of fitting parameters or weights. Dimension (1 x n)
    cost_history: Conatins value of cost for each iteration. 1D array. Dimansion(m x 1)
    """
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.transpose().dot(errors);
        theta = theta - sum_delta;
        cost_history[i] = compute_cost(X, y, theta)
    return theta, cost_history

# %% [markdown]
# Problem 1 (For X1)

# %%
X = df.values[:, 0] # get input values from first column
y = df.values[:, 3] # get output values from second column
m = len(y) # Number of training examples
print('X = ', X[: 5]) # Show only first 5 records
print('y = ', y[: 5])
print('m = ', m)
# Out:
# X =  [0.         0.04040404 0.08080808 0.12121212 0.16161616]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100
# X =  [0.         0.04040404 0.08080808 0.12121212 0.16161616]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100

# %%
plt.scatter(X,y, color='red',marker= '+')
plt.grid()
#plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
#Lets create a matrix with single column of ones
X_0 = np.ones((m, 1))
# print(X_0[:5])
# print(X.shape)

# Using reshape function convert X 1D array to 2D array
X_1 = X.reshape(m, 1)
# print(X_1.shape)
# X_1[:10]

# Lets use hstack() function from numpy to stack X_0 and X_1 horizontally (i.e. column
# This will be our final X matrix (feature matrix)
X = np.hstack((X_0, X_1))
# X[:5]

theta = np.zeros(2)
# theta

# %%
# Lets compute the cost for theta values
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
theta = [0., 0.]
iterations = 1500;
alpha = 0.01;

theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 5.71850653 -1.9568206 ]
# cost_history = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
# Since X is list of list (feature matrix) lets take values of column of index 1 only
plt.scatter(X[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='green', label='Linear Regression')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations + 1),cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %% [markdown]
# Problem 1(For X2)

# %%
X = df.values[:, 1] # get input values from first column
y = df.values[:, 3] # get output values from second column
m = len(y) # Number of training examples
print('X = ', X[: 5]) # Show only first 5 records
print('y = ', y[: 5])
print('m = ', m)
# Out:
# X =  [3.44       0.1349495  0.82989899 1.52484848 2.21979798]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100

# %%
plt.scatter(X,y, color='red',marker= '+')
plt.grid()
#plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
#Lets create a matrix with single column of ones
X_0 = np.ones((m, 1))

# Using reshape function convert X 1D array to 2D array
X_1 = X.reshape(m, 1)
# Lets use hstack() function from numpy to stack X_0 and X_1 horizontally (i.e. column
# This will be our final X matrix (feature matrix)
X = np.hstack((X_0, X_1))

theta = np.zeros(2)

# %%
# Lets compute the cost for theta values
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
iterations = 1500;
alpha = 0.01;

theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [0.71988473 0.56390334]
# cost_history = [5.29831663 5.09909109 4.92356115 ... 3.5993997  3.59939955 3.5993994 ]

# %%
# Since X is list of list (feature matrix) lets take values of column of index 1 only
plt.scatter(X[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='green', label='Linear Regression')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations + 1),cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %% [markdown]
# Problem 1 (For X3)

# %%
X = df.values[:, 2] # get input values from first column
y = df.values[:, 3] # get output values from second column
m = len(y) # Number of training examples
print('X = ', X[: 5]) # Show only first 5 records
print('y = ', y[: 5])
print('m = ', m)
# Out:
# X =  [0.44       0.88848485 1.3369697  1.78545454 2.23393939]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100

# %%
plt.scatter(X,y, color='red',marker= '+')
plt.grid()
#plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
#Lets create a matrix with single column of ones
X_0 = np.ones((m, 1))

# Using reshape function convert X 1D array to 2D array
X_1 = X.reshape(m, 1)
# Lets use hstack() function from numpy to stack X_0 and X_1 horizontally (i.e. column
# This will be our final X matrix (feature matrix)
X = np.hstack((X_0, X_1))

theta = np.zeros(2)

# %%
# Lets compute the cost for theta values
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
iterations = 1500;
alpha = 0.01;

theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 2.78048129 -0.48451631]
# cost_history = [5.40768785 5.30397076 5.21178297 ... 3.63053597 3.6305311  3.63052625]

# %%
# Since X is list of list (feature matrix) lets take values of column of index 1 only
plt.scatter(X[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='green', label='Linear Regression')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations + 1),cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %% [markdown]
# Problem 2 (With all three explanatory variables)

# %%
X_3 = df.values[:, 0:3] # get input values from first column
print(X.shape)
y = df.values[:, 3] # get output values from second column
m = len(y) # Number of training examples
print('X = ', X_3[: 5]) # Show only first 5 records
print('y = ', y[: 5])
print('m = ', m)
# Out:
# (100, 7)
# X =  [[0.         3.44       0.44      ]
#  [0.04040404 0.1349495  0.88848485]
#  [0.08080808 0.82989899 1.3369697 ]
#  [0.12121212 1.52484848 1.78545454]
#  [0.16161616 2.21979798 2.23393939]]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100

# %%
plt.scatter(X_3[:,0],y, color='red',marker= '+')
plt.scatter(X_3[:,1],y, color='green',marker= '*')
plt.scatter(X_3[:,2],y, color='blue',marker= '.')
plt.grid()
#plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
X_0 = np.ones((m, 1))
X = np.hstack((X_0, X_3))
theta = np.zeros(4)
iterations = 500;
alpha = .01;

# %%
# Lets compute the cost for theta values
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0, theta_1, theta_2 and theta_3 =', cost)
# Out:
# The cost for given values of theta_0, theta_1, theta_2 and theta_3 = 5.524438459196242

# %%
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
# print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 2.16125586 -1.55553751  1.05260964  0.19466187]

# %%
# Since X is list of list (feature matrix) lets take values of column of index 1 only
plt.scatter(X[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='green', label='Linear Regression')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, iterations + 1),cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
#Predict the value of y for new (X1, X2, X3) values (1, 1, 1), for (2, 0, 4), and for (3, 2, 1)

# %%
new_arr = np.array([[1, 1, 1],
                    [2, 0, 4],
                    [3, 2, 1]])

new_arr_0 = np.ones((len(new_arr), 1))
new_arr_x = np.hstack((new_arr_0, new_arr))
new_y = new_arr_x.dot(theta)

# %%
new_y
# Out:
# array([ 1.85298986, -0.17117167, -0.20547552])
