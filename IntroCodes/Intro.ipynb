# %% [markdown]
# <a href="https://colab.research.google.com/github/HamedTabkhi/Intro-to-ML/blob/main/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x=np.array([[1,2,3],[4,5,6]])
print("x:\n{}".format(x))
# Out:
# x:
# [[1 2 3]
#  [4 5 6]]

# %%
import matplotlib.pyplot as plt
# Generate a sequence of numbers from -10 to 10 with 100 steps in between
x=np.linspace(-10,10,100)
# Create a second array using sine
y=np.sin(x)
# The plot function makes a line chart of one array against another
plt.plot(x,y,marker="+")

# %%
from IPython.display import display
import pandas as pd

# Create a simple dataframe
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Occupation': ['Engineer', 'Doctor', 'Artist']
})

# Display the dataframe
display(df)
# Out:
#       Name  Age Occupation
# 0    Alice   25   Engineer
# 1      Bob   30     Doctor
# 2  Charlie   35     Artist

# %%
# Select all rows that have an age column greater than 30
display(df[df.Age > 30])
# Out:
#       Name  Age Occupation
# 2  Charlie   35     Artist

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Occupation': ['Engineer', 'Doctor', 'Artist']
}

df2 = pd.DataFrame(data)
# Display the dataframe
display(df)
# Out:
#       Name  Age Occupation
# 0    Alice   25   Engineer
# 1      Bob   30     Doctor
# 2  Charlie   35     Artist
